# %%
# import shutil
# shutil.unpack_archive('../data/medium-articles-dataset.zip', '../data/')

# %%
import pandas as pd
import time
from text_preprocessing import *
import json
import pickle
from tqdm import tqdm
import spacy
from rebel import spacy_component

# %% [markdown]
# ### Relation extraction runs in cmd : ```run_rebel_medium.py```

# %% [markdown]
# ### Extracted relations analysis

# %%
with open('medium_rel_extracted_from_cmd.json', 'r') as fp:
    data = json.load(fp)

# %%
relation_types = list()
for i in tqdm(list(data.keys())[:-1], total=len(data.keys())):
    relation_types.append(data[i]['relation'])
# Out:
# 100%|█████████▉| 7444/7445 [00:00<00:00, 600731.12it/s]

# %%
unique_relation_types_counter = dict(Counter(relation_types))

# %%
len(unique_relation_types_counter)
# Out:
# 116

# %%
unique_relation_types_vc = dict(sorted(unique_relation_types_counter.items(), key=lambda t: t[1], reverse=True))

# %%
unique_relation_types_vc
# Out:
# {'main subject': 1327,
#  'facet of': 878,
#  'has part': 549,
#  'subclass of': 515,
#  'part of': 484,
#  'instance of': 439,
#  'use': 358,
#  'different from': 316,
#  'followed by': 260,
#  'opposite of': 196,
#  'programming language': 174,
#  'follows': 131,
#  'said to be the same as': 117,
#  'point in time': 99,
#  'studies': 97,
#  'is a list of': 95,
#  'uses': 87,
#  'field of this occupation': 84,
#  'product or material produced': 83,
#  'author': 74,
#  'practiced by': 61,
#  'studied by': 59,
#  'field of work': 59,
#  'performer': 56,
#  'used by': 54,
#  'has effect': 51,
#  'developer': 48,
#  'part of the series': 41,
#  'owned by': 37,
#  'genre': 34,
#  'operating system': 33,
#  'country': 32,
#  'has cause': 31,
#  'owner of': 30,
#  'based on': 29,
#  'notable work': 25,
#  'located in the administrative territorial entity': 23,
#  'derivative work': 22,
#  'platform': 20,
#  'present in work': 20,
#  'influenced by': 17,
#  'sport': 16,
#  'publisher': 15,
#  'characters': 15,
#  'industry': 15,
#  'publication date': 13,
#  'occupation': 12,
#  'named after': 12,
#  'published in': 12,
#  'subsidiary': 12,
#  'participant': 10,
#  'number of episodes': 10,
#  'location': 9,
#  'number of participants': 8,
#  'manufacturer': 8,
#  'creator': 8,
#  'parent organization': 8,
#  'presenter': 7,
#  'replaced by': 6,
#  'replaces': 6,
#  'participant in': 4,
#  'original broadcaster': 4,
#  'depicts': 4,
#  'location of formation': 3,
#  'language used': 3,
#  'distributed by': 3,
#  'continent': 3,
#  'applies to jurisdiction': 3,
#  'member of': 3,
#  'followed by Jobs How Great is the Need?': 2,
#  'diplomatic relation': 2,
#  'twinned administrative body': 2,
#  'sports season of league or competition': 2,
#  'organizer': 2,
#  'language of work or name': 2,
#  'headquarters location': 2,
#  'conferred by': 2,
#  'employer': 2,
#  'significant event': 2,
#  'movement': 2,
#  'stock exchange': 2,
#  'inception': 2,
#  'founded by': 2,
#  'opposite of manage what you can’t measure': 2,
#  'winner': 2,
#  'sibling': 2,
#  'cast member': 2,
#  'shares border with': 2,
#  'spouse': 2,
#  'authority': 1,
#  'part of Future Ally': 1,
#  'work period (start)': 1,
#  'constellation': 1,
#  'parent taxon': 1,
#  'member of sports team': 1,
#  'length': 1,
#  'court': 1,
#  'crosses': 1,
#  'has parts of the class': 1,
#  'followed by Nobody’s Permission to Create Your Own Reality': 1,
#  'office held by head of the organization': 1,
#  'ranking': 1,
#  'followed by You Got a New Job!': 1,
#  'part of Succeed, You Have to Work Even When You Don’t Feel Like It': 1,
#  'contains administrative territorial entity': 1,
#  'event distance': 1,
#  'religious order': 1,
#  'political ideology': 1,
#  'discoverer or inventor': 1,
#  'opposite of Creative To Create': 1,
#  'award received': 1,
#  'architectural style': 1,
#  'number of steps': 1,
#  'located in or next to body of water': 1,
#  'narrative location': 1,
#  'country of origin': 1}

# %%
from matplotlib import pyplot as plt
import itertools

# %%
plt.figure(figsize=(16, 12))
plt.bar(*zip(*dict(itertools.islice(unique_relation_types_vc.items(), 20)).items()))
plt.xticks(rotation=85, fontsize=14)
plt.show()

# %%
example_rel_type = list()
for k, v in tqdm(list(data.items())[:-1], total=len(data.items())):
    if v['relation'] == 'main subject':
        example_rel_type.append((k, v))
# Out:
# 100%|█████████▉| 7444/7445 [00:00<00:00, 633417.17it/s]

# %%
example_rel_type
# Out:
# [('An Easy Introduction to SQL for Data Scientists->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'An Easy Introduction to SQL for Data Scientists',
#    'tail': 'SQL'}),
#  ('How To Retain More From The Books You Read->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How To Retain More From The Books You Read',
#    'tail': 'Retain More From The Books You Read'}),
#  ('Living as an Empath w->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Living as an Empath',
#    'tail': 'Empath'}),
#  ('Why Sometimes it’s Better to Sell Picks and Shovels than Mine for Gold->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Why Sometimes it’s Better to Sell Picks and Shovels than Mine for Gold',
#    'tail': 'Why Sometimes it’s Better to Sell Picks and Shovels than Mine for Gold'}),
#  ('Death Stranding Is About the Fracturing Soul of America->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Death Stranding',
#    'tail': 'Fracturing Soul of America'}),
#  ('A Framework for Creativity->(1, 3)',
#   {'relation': 'main subject',
#    'head': 'Framework for Creativity',
#    'tail': 'Creativity'}),
#  ('I Was Miserable as a Suburban Stay Home Mom->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'I Was Miserable as a Suburban Stay Home Mom',
#    'tail': 'Stay Home Mom'}),
#  ('Why Reflection Opens Up Your World to the Present and Future->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Reflection Opens Up Your World to the Present and Future',
#    'tail': 'Reflection'}),
#  ('Here’s Why You Should Never Undermine the Meaning of Your Life->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'Here’s Why You Should Never Undermine the Meaning of Your Life',
#    'tail': 'Meaning of Your Life'}),
#  ('How To Limit Your Exposure To The Surveillance Capitalism->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'How To Limit Your Exposure To The Surveillance Capitalism',
#    'tail': 'Surveillance Capitalism'}),
#  ('How to Provide Support to a Grieving Friend->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How to Provide Support to a Grieving Friend',
#    'tail': 'Grieving Friend'}),
#  ('3 Keys to Drive Away Daily Stress->(0, 5)',
#   {'relation': 'main subject',
#    'head': '3 Keys to Drive Away Daily Stress',
#    'tail': 'Daily Stress'}),
#  ('The Call for a New Device for Data Scientists->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'The Call for a New Device for Data Scientists',
#    'tail': 'Data Scientists'}),
#  ('How to Live in the Present and Make Your Time Count->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How to Live in the Present and Make Your Time Count',
#    'tail': 'Live in the Present and Make Your Time Count'}),
#  ('Should You Skip the Caffeine?->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Should You Skip the Caffeine',
#    'tail': 'Caffeine'}),
#  ('How to be Terrible at Everything->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to be Terrible at Everything',
#    'tail': 'Terrible at Everything'}),
#  ('Are We Losing Our Real Life Relationships With Each Other?->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Are We Losing Our Real Life Relationships With Each Other',
#    'tail': 'Real Life Relationships With Each Other'}),
#  ('Strokes of Fortune->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Strokes of Fortune',
#    'tail': 'Fortune'}),
#  ('Here’s How To Edit Your Scenes The Right Way->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Here’s How To Edit Your Scenes',
#    'tail': 'Edit Your Scenes'}),
#  ('Here’s How To Edit Your Scenes The Right Way->(7, 7)',
#   {'relation': 'main subject',
#    'head': 'The Right Way',
#    'tail': 'The Right Way'}),
#  ('A Reason for Being Using Belief Statements to Uncover your Purpose->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'A Reason for Being Using Belief Statements to Uncover your Purpose',
#    'tail': 'Purpose'}),
#  ('Scheduled Happiness->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Scheduled Happiness',
#    'tail': 'Happiness'}),
#  ('Why a Style Guide Is Just Good Business->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Why a Style Guide Is Just Good Business',
#    'tail': 'Style Guide'}),
#  ('Unexpected Things I Don’t Miss About Freelance->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Unexpected Things I Don’t Miss About Freelance',
#    'tail': 'Freelance'}),
#  ('The Power of Unconventional Marketing->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Power of Unconventional Marketing',
#    'tail': 'Unconventional Marketing'}),
#  ('What If Your Morals Clash with Your Work?->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'What If Your Morals Clash with Your Work',
#    'tail': 'Morals Clash with Your Work'}),
#  ('Smashing Through Creative Blocks->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Smashing Through Creative Blocks',
#    'tail': 'Creative Blocks'}),
#  ('Not Another Meeting! 5 Ways to Reduce Meeting Agony->(4, 8)',
#   {'relation': 'main subject',
#    'head': '5 Ways to Reduce Meeting Agony',
#    'tail': 'Meeting Agony'}),
#  ('Your Short Sentences Are Overrated->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Your Short Sentences Are Overrated',
#    'tail': 'Short Sentences'}),
#  ('Use the Three C’s of Good Writing to Avoid Writing Pitfalls->(2, 10)',
#   {'relation': 'main subject',
#    'head': 'Three C’s of Good Writing',
#    'tail': 'Writing Pitfalls'}),
#  ('There Is No Such Thing As A Bad Book->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'There Is No Such Thing As A Bad Book',
#    'tail': 'Bad Book'}),
#  ('How Olfactory Cues Can Drive and Shape Your Story->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Olfactory Cues Can Drive and Shape Your Story',
#    'tail': 'Olfactory Cues'}),
#  ('What Writer’s Block is Trying to Tell You->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'What Writer’s Block is Trying to Tell You',
#    'tail': 'Writer’s Block'}),
#  ('A Roadmap for Digital Transformation->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'A Roadmap for Digital Transformation',
#    'tail': 'Digital Transformation'}),
#  ('Obesity How to Believe in Yourself->(1, 0)',
#   {'relation': 'main subject',
#    'head': 'How to Believe in Yourself',
#    'tail': 'Obesity'}),
#  ('The Disruptor CMO Playbook->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'The Disruptor CMO Playbook',
#    'tail': 'CMO Playbook'}),
#  ('How To Build a Pipeline of Freelance Leads->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How To Build a Pipeline of Freelance Leads',
#    'tail': 'Pipeline of Freelance Leads'}),
#  ('I Bought a Lap Desk and I Feel Guilty About It->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'I Bought a Lap Desk and I Feel Guilty About It',
#    'tail': 'Lap Desk'}),
#  ('How to Advertise the Disgusting->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How to Advertise the Disgusting',
#    'tail': 'Advertise the Disgusting'}),
#  ('An Introduction to Recurrent Neural Networks for Beginners->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'An Introduction to Recurrent Neural Networks for Beginners',
#    'tail': 'Recurrent Neural Networks'}),
#  ('A gentle introduction to Recommendation Systems->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'A gentle introduction to Recommendation Systems',
#    'tail': 'Recommendation Systems'}),
#  ('The Complete Guide to Decision Trees->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Complete Guide to Decision Trees',
#    'tail': 'Decision Trees'}),
#  ('Street Lanes Finder Detecting Street Lanes for Self Driving Cars 🚗->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Street Lanes Finder',
#    'tail': 'Street Lanes for Self Driving Cars'}),
#  ('Predict Employee Retention->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Predict Employee Retention',
#    'tail': 'Employee Retention'}),
#  ('What if Your Colleague is a Robot->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'What if Your Colleague is a Robot',
#    'tail': 'Robot'}),
#  ('What To Do When You’re Living In Limbo->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'What To Do When You’re Living In Limbo',
#    'tail': 'Limbo'}),
#  ('What I Learned From Running a Business With a Narcissist->(0, 9)',
#   {'relation': 'main subject',
#    'head': 'What I Learned From Running a Business With a Narcissist',
#    'tail': 'Narcissist'}),
#  ('The Real Reason Why Motion Smoothing Is a Thing->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Real Reason Why Motion Smoothing Is a Thing',
#    'tail': 'Motion Smoothing'}),
#  ('The Cosmic Limit of Finite Life->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Cosmic Limit of Finite Life',
#    'tail': 'Finite Life'}),
#  ('How to Develop Unwavering Confidence->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to Develop Unwavering Confidence',
#    'tail': 'Unwavering Confidence'}),
#  ('3 Ways You Can Learn to Embrace Suffering->(0, 6)',
#   {'relation': 'main subject',
#    'head': '3 Ways You Can Learn to Embrace Suffering',
#    'tail': 'Embrace Suffering'}),
#  ('How To Maintain Privacy When Big Brother is Watching You->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How To Maintain Privacy When Big Brother is Watching You',
#    'tail': 'Privacy When Big Brother is Watching You'}),
#  ('Cybersecurity In Industrial Control Systems The Evolving Threat Landscape->(5, 6)',
#   {'relation': 'main subject',
#    'head': 'The Evolving Threat Landscape',
#    'tail': 'Evolving Threat Landscape'}),
#  ('Finding Your Happy What Is It and Where Can You Find It?->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Finding Your Happy',
#    'tail': 'Finding Your Happy'}),
#  ('What’s the Truth on What to Eat?->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'What’s the Truth on What to Eat',
#    'tail': 'Truth on What to Eat'}),
#  ('Where You Need to Be if You Want to Get Rich Online->(0, 9)',
#   {'relation': 'main subject',
#    'head': 'Where You Need to Be if You Want to Get Rich Online',
#    'tail': 'Get Rich Online'}),
#  ('How Winning the Lottery Would Ruin My Life->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Winning the Lottery Would Ruin My Life',
#    'tail': 'Winning the Lottery'}),
#  ('Are You Too Scared to Start Investing?->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Are You Too Scared to Start Investing',
#    'tail': 'Investing'}),
#  ('End Writing Procrastination Now->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'End Writing Procrastination Now',
#    'tail': 'Procrastination Now'}),
#  ('Living the holiday life->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Living the holiday life',
#    'tail': 'holiday'}),
#  ('Like a Basket, we Weave our Story->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Like a Basket, we Weave our Story',
#    'tail': 'Basket'}),
#  ('Java Why You Remove Unused Imports->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Java Why You Remove Unused Imports',
#    'tail': 'Why You Remove Unused Imports'}),
#  ('How To Master Your Mobility in 15 Minutes a Day->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How To Master Your Mobility in 15 Minutes a Day',
#    'tail': 'Mobility'}),
#  ('You’ll Never Feel Good Enough to Start Building an Audience->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'You’ll Never Feel Good Enough to Start Building an Audience',
#    'tail': 'Audience'}),
#  ('The Art of Asking the Right Questions While Hiring Remotely->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Art of Asking the Right Questions While Hiring Remotely',
#    'tail': 'Asking the Right Questions While Hiring Remotely'}),
#  ('Socialism Is For Rich People->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Socialism Is For Rich People',
#    'tail': 'Socialism'}),
#  ('3 Life Lessons from the Rubik’s Cube->(0, 5)',
#   {'relation': 'main subject',
#    'head': '3 Life Lessons from the Rubik’s Cube',
#    'tail': 'Rubik’s Cube'}),
#  ('The Importance of Investing in Yourself->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Importance of Investing in Yourself',
#    'tail': 'Investing in Yourself'}),
#  ('For A Successful Life, Diversify Your Sources of Happiness->(5, 1)',
#   {'relation': 'main subject',
#    'head': 'Diversify Your Sources of Happiness',
#    'tail': 'A Successful Life, Diversify Your Sources of Happiness'}),
#  ('Why Going To College Was A Mistake->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Going To College Was A Mistake',
#    'tail': 'Going To College Was A Mistake'}),
#  ('The Illusion Of Quick Wins->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Illusion Of Quick Wins',
#    'tail': 'Quick Wins'}),
#  ('Does Your Writing Stink?->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Does Your Writing Stink',
#    'tail': 'Writing Stink'}),
#  ('Writing through Trial and Error->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Writing through Trial and Error',
#    'tail': 'Trial and Error'}),
#  ('What I Learned Writing a Novel You Will Probably Never Read->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'What I Learned Writing a Novel',
#    'tail': 'Writing a Novel'}),
#  ('The Future of The World->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Future of The World',
#    'tail': 'The World'}),
#  ('What Is Neuralink A Look At What It Is, What It Wants to Be, and What It Could Become->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'What Is Neuralink',
#    'tail': 'Neuralink'}),
#  ('The Hundred Page Machine Learning Book Book Review->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Hundred Page Machine Learning Book Book Review',
#    'tail': 'Machine Learning'}),
#  ('A Quant’s Intro to Portfolio Hedging->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'A Quant’s Intro to Portfolio Hedging',
#    'tail': 'Portfolio Hedging'}),
#  ('Deep Learning on a Budget->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Deep Learning on a Budget',
#    'tail': 'Deep Learning'}),
#  ('How to Ease the Pain of Working with Imbalanced Data->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'How to Ease the Pain of Working with Imbalanced Data',
#    'tail': 'Imbalanced Data'}),
#  ('Response Formats and the Moon Landing->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Response Formats and the Moon Landing',
#    'tail': 'Moon Landing'}),
#  ('The Ultimate Guide to On Perm Kubernetes->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Ultimate Guide to On Perm Kubernetes',
#    'tail': 'On Perm Kubernetes'}),
#  ('How to Stop Mindlessly Buying Clothes->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to Stop Mindlessly Buying Clothes',
#    'tail': 'Mindlessly Buying Clothes'}),
#  ('Why Top Sites Are Easy To Understand->(1, 0)',
#   {'relation': 'main subject',
#    'head': 'Top Sites Are Easy To Understand',
#    'tail': 'Why Top Sites Are Easy To Understand'}),
#  ('How to be Radically Productive and Finish that Project with 3 Life Tested Principles->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'How to be Radically Productive and Finish that Project',
#    'tail': '3 Life Tested Principles'}),
#  ('Five Tips for Getting a Remote Job->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Five Tips for Getting a Remote Job',
#    'tail': 'Remote Job'}),
#  ('I’ve Worked at Home for 7 Years. Here’s Everything I Know About Getting Stuff Done.->(9, 15)',
#   {'relation': 'main subject',
#    'head': 'Here’s Everything I Know About Getting Stuff Done',
#    'tail': 'Getting Stuff Done'}),
#  ('5 Ways to Find Meaning at Work->(0, 4)',
#   {'relation': 'main subject',
#    'head': '5 Ways to Find Meaning at Work',
#    'tail': 'Meaning at Work'}),
#  ('The secret to being happy all the time.->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The secret to being happy all the time',
#    'tail': 'happy'}),
#  ('The Introvert’s Guide To Surviving Conferences & Industry Events->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'The Introvert’s Guide To Surviving Conferences & Industry Events',
#    'tail': 'Conferences & Industry Events'}),
#  ('The Brain of a Murderer->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Brain of a Murderer',
#    'tail': 'Murderer'}),
#  ('The Self Sabotaging Art Of Perfectionism->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The Self Sabotaging Art Of Perfectionism',
#    'tail': 'Perfectionism'}),
#  ('25 Simple Ways To Double Your Cash flow Without Firing Your Staff->(0, 6)',
#   {'relation': 'main subject',
#    'head': '25 Simple Ways To Double Your Cash flow Without Firing Your Staff',
#    'tail': 'Cash flow'}),
#  ('What Software Design Patterns Can Teach Organisations About Effective Communication->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'What Software Design Patterns Can Teach Organisations About Effective Communication',
#    'tail': 'Effective Communication'}),
#  ('What Made You Good Is Not Always Enough to Make You Great->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'What Made You Good Is Not Always Enough to Make You Great',
#    'tail': 'Good Is Not Always Enough to Make You Great'}),
#  ('Two Ways to Combat Anxiety Like a Stoic->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Two Ways to Combat Anxiety Like a Stoic',
#    'tail': 'Anxiety'}),
#  ('The Ultimate Guide To Living A Stylish Life Without Overspending->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Ultimate Guide To Living A Stylish Life Without Overspending',
#    'tail': 'Living A Stylish Life Without Overspending'}),
#  ('The Question You Should ask Yourself If you Want to Know if you are Managing Your Time the Right Way->(0, 14)',
#   {'relation': 'main subject',
#    'head': 'The Question You Should ask Yourself If you Want to Know if you are Managing Your Time',
#    'tail': 'Managing Your Time'}),
#  ('Build it and They Will Come Why This is the Worst Advice in Business->(0, 13)',
#   {'relation': 'main subject',
#    'head': 'Build it and They Will Come Why This is the Worst Advice in Business',
#    'tail': 'Business'}),
#  ('The Best Way to Respond to Rejection Don’t.->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'The Best Way to Respond to Rejection Don’t.',
#    'tail': 'Rejection'}),
#  ('How I Got Out of My Writing Slump And How You Can Too->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How I Got Out of My Writing Slump',
#    'tail': 'Writing Slump'}),
#  ('What’s the most real thing?->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'What’s the most real thing',
#    'tail': 'most real thing'}),
#  ('How Much Do You Know About Certificates of Deposit? Your Questions Answered->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How Much Do You Know About Certificates of Deposit',
#    'tail': 'Certificates of Deposit'}),
#  ('How Much Do You Know About Certificates of Deposit? Your Questions Answered->(10, 10)',
#   {'relation': 'main subject',
#    'head': 'Your Questions Answered',
#    'tail': 'Your Questions Answered'}),
#  ('Buzzwords to Realism The Fundamental Necessity to Institute Quality Healthcare for Everyone->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'Buzzwords to Realism',
#    'tail': 'Quality Healthcare for Everyone'}),
#  ('How To Handle Stressful Situations While Maintaining Your Composure->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How To Handle Stressful Situations While Maintaining Your Composure',
#    'tail': 'Stressful Situations While Maintaining Your Composure'}),
#  ('Where Does Influencer Responsibility Begin and End?->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Where Does Influencer Responsibility Begin and End',
#    'tail': 'Influencer Responsibility'}),
#  ('The Comprehensive Guide to Staying on Track With Your Projects->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Comprehensive Guide to Staying on Track With Your Projects',
#    'tail': 'Staying on Track With Your Projects'}),
#  ('Can You Embarrass People Into Environmental Awareness?->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Can You Embarrass People Into Environmental Awareness',
#    'tail': 'Environmental Awareness'}),
#  ('7 Machine Learning lessons that stuck with me this year->(0, 1)',
#   {'relation': 'main subject',
#    'head': '7 Machine Learning lessons that stuck with me this year',
#    'tail': 'Machine Learning'}),
#  ('The curious case of toilet paper and facial recognition->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The curious case of toilet paper and facial recognition',
#    'tail': 'toilet paper'}),
#  ('How to Hack Your Way into Online Success. NOT. ->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How to Hack Your Way into Online Success',
#    'tail': 'Hack Your Way'}),
#  ('Why Mentoring Someone Can Change Your Life->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Mentoring Someone Can Change Your Life',
#    'tail': 'Mentoring Someone'}),
#  ('Girls Just Don’t Like Computer Science Isn’t a Good Enough Excuse->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Girls Just Don’t Like Computer Science Isn’t a Good Enough Excuse',
#    'tail': 'Computer Science'}),
#  ('How to Create and Accomplish Your Long term Goals->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How to Create and Accomplish Your Long term Goals',
#    'tail': 'Long term Goals'}),
#  ('The Emotional Revolution->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Emotional Revolution',
#    'tail': 'Emotional Revolution'}),
#  ('Keystone Habits How To Transform Your Life Patterns->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Keystone Habits',
#    'tail': 'Life Patterns'}),
#  ('Kill the Thought Verbs! Get Readers Involved->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Kill the Thought Verbs',
#    'tail': 'Thought Verbs'}),
#  ('The Art of Platform Governance->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Art of Platform Governance',
#    'tail': 'Platform Governance'}),
#  ('Keeping Data Science Simple->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Keeping Data Science Simple',
#    'tail': 'Data Science'}),
#  ('A quick start guide to choosing accessible colours->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'A quick start guide to choosing accessible colours',
#    'tail': 'accessible colours'}),
#  ('Wiping out your Instagram sins a UX case study->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Wiping out your Instagram sins',
#    'tail': 'UX'}),
#  ('4 Powerful Strategies That Will 40x Your Productivity->(0, 7)',
#   {'relation': 'main subject',
#    'head': '4 Powerful Strategies That Will 40x Your Productivity',
#    'tail': 'Productivity'}),
#  ('The Toxic Side Effects Of Trying To Plan Your Life->(1, 5)',
#   {'relation': 'main subject',
#    'head': 'Toxic Side Effects Of Trying To Plan Your Life',
#    'tail': 'Trying To Plan Your Life'}),
#  ('The Essential Anti Anxiety Guide to Your Best Sleep->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Essential Anti Anxiety Guide to Your Best Sleep',
#    'tail': 'Essential Anti Anxiety'}),
#  ('How To Write A Joke->(0, 4)',
#   {'relation': 'main subject', 'head': 'How To Write A Joke', 'tail': 'Joke'}),
#  ('Why America needs a Basic Income->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Why America needs a Basic Income',
#    'tail': 'Basic Income'}),
#  ('Why Self Reliance is More Important Than Ever->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Self Reliance is More Important Than Ever',
#    'tail': 'Self Reliance'}),
#  ('Dive Really Deep into YOLO v3 A Beginner’s Guide->(6, 7)',
#   {'relation': 'main subject',
#    'head': 'A Beginner’s Guide',
#    'tail': 'Beginner’s Guide'}),
#  ('Cryptography Crash Course for the Intimidated->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Cryptography Crash Course for the Intimidated',
#    'tail': 'Cryptography'}),
#  ('Deep Dive into SF Crime->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Deep Dive into SF Crime',
#    'tail': 'SF Crime'}),
#  ('The Age of the Electric Bicycle->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Age of the Electric Bicycle',
#    'tail': 'Electric Bicycle'}),
#  ('The ghost in the machine 15 practical steps towards becoming anonymous online->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The ghost in the machine',
#    'tail': '15 practical steps towards becoming anonymous online'}),
#  ('7 Steps to Become a Paid Freelance Writer->(0, 5)',
#   {'relation': 'main subject',
#    'head': '7 Steps to Become a Paid Freelance Writer',
#    'tail': 'Paid Freelance Writer'}),
#  ('When Confidence is Scarce->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'When Confidence is Scarce',
#    'tail': 'Scarce'}),
#  ('The Crippling Guilt of Being Away from Social Media->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Crippling Guilt of Being Away from Social Media',
#    'tail': 'Being Away from Social Media'}),
#  ('In Defense of the Success Industry->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'In Defense of the Success Industry',
#    'tail': 'Success Industry'}),
#  ('A Proposed Cure to Burnout->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'A Proposed Cure to Burnout',
#    'tail': 'Burnout'}),
#  ('10 Things I’ve Learned In My First Year Of Self Publishing And 3 I Haven’t ->(0, 10)',
#   {'relation': 'main subject',
#    'head': '10 Things I’ve Learned In My First Year Of Self Publishing And 3 I Haven’t',
#    'tail': 'Self Publishing'}),
#  ('Five Reasons Why Change Can Be So Hard And Ways to Increase Your Success ->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Five Reasons Why Change Can Be So Hard And Ways to Increase Your Success',
#    'tail': 'Change Can Be So Hard And Ways to Increase Your Success'}),
#  ('The Reasons Behind Burnout and How To Deal With It->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Reasons Behind Burnout and How To Deal With It',
#    'tail': 'Burnout'}),
#  ('On Jealousy->(0, 1)',
#   {'relation': 'main subject', 'head': 'On Jealousy', 'tail': 'Jealousy'}),
#  ('The Tortoises That Beat Humans to the Moon->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Tortoises That Beat Humans to the Moon',
#    'tail': 'Tortoises'}),
#  ('Mental Models How the Inversion Principle Could Change Your Life->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Mental Models How the Inversion Principle Could Change Your Life',
#    'tail': 'Inversion Principle'}),
#  ('Publishing Everyday->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Publishing Everyday',
#    'tail': 'Everyday'}),
#  ('You May Be Grieving and Not Even Know It->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'You May Be Grieving and Not Even Know It',
#    'tail': 'Grieving'}),
#  ('12 Ways to Spend Less Time on Your Phone->(0, 3)',
#   {'relation': 'main subject',
#    'head': '12 Ways to Spend Less Time on Your Phone',
#    'tail': 'Spend Less Time on Your Phone'}),
#  ('I Learned This 3 Step System For Organizing Creativity From A Top Music Conservatory->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'I Learned This 3 Step System For Organizing Creativity From A Top Music Conservatory',
#    'tail': '3 Step System For Organizing Creativity'}),
#  ('5 Crucial Questions for High Performance Marketing->(0, 4)',
#   {'relation': 'main subject',
#    'head': '5 Crucial Questions for High Performance Marketing',
#    'tail': 'High Performance Marketing'}),
#  ('The Illusion of Treasure->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Illusion of Treasure',
#    'tail': 'Illusion of Treasure'}),
#  ('How to Start a New Year with the Same Old You->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How to Start a New Year with the Same Old You',
#    'tail': 'New Year'}),
#  ('What to Do Before Your New Year Resolutions Fail->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'What to Do Before Your New Year Resolutions Fail',
#    'tail': 'New Year Resolutions Fail'}),
#  ('Writing For An Audience->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Writing For An Audience',
#    'tail': 'Audience'}),
#  ('Bending Bitcoin The Principle of Hard Money->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Bending Bitcoin',
#    'tail': 'The Principle of Hard Money'}),
#  ('Why Do Financial Models Break?->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Why Do Financial Models Break',
#    'tail': 'Financial Models Break'}),
#  ('AI Fairness Explanation of Disparate Impact Remover->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'AI Fairness Explanation of Disparate Impact Remover',
#    'tail': 'Disparate Impact Remover'}),
#  ('Can AI Robots Rebel Against Us, as Shown in Films?->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Can AI Robots Rebel Against Us, as Shown in Films',
#    'tail': 'AI Robots Rebel Against Us'}),
#  ('Watch the rise of plastics in our oceans Part one->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Watch the rise of plastics in our oceans Part one',
#    'tail': 'plastics in our oceans'}),
#  ('A Brief Primer on Data Science and What It Can Do for Your Business->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'A Brief Primer on Data Science and What It Can Do for Your Business',
#    'tail': 'Data Science'}),
#  ('The Secret to Knowing the Unknowable Predictive Analytics->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'The Secret to Knowing the Unknowable Predictive Analytics',
#    'tail': 'Predictive Analytics'}),
#  ('Innocent Interpretations for Some Suspicious Statistics General Election Data Exploration. part 1 ->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Innocent Interpretations for Some Suspicious Statistics',
#    'tail': 'General Election Data Exploration'}),
#  ('Simplicity sells->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Simplicity sells',
#    'tail': 'Simplicity'}),
#  ('The 20 Keys to Creating an Inspiring Brand Story->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'The 20 Keys to Creating an Inspiring Brand Story',
#    'tail': 'Brand Story'}),
#  ('FAMGA Bet On Healthcare But Where Do They Go?->(2, 3)',
#   {'relation': 'main subject', 'head': 'On Healthcare', 'tail': 'Healthcare'}),
#  ('On Ageism and a Bad Haircut->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'On Ageism and a Bad Haircut',
#    'tail': 'Ageism'}),
#  ('My Life As a Social Media Influencer->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'My Life As a Social Media Influencer',
#    'tail': 'Social Media Influencer'}),
#  ('Why I Use a Pen Name and How I Created One->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Why I Use a Pen Name',
#    'tail': 'Pen Name'}),
#  ('The Mechanics of Attribution Quoting &amp Paraphrasing->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Mechanics of Attribution Quoting &amp Paraphrasing',
#    'tail': 'Attribution Quoting &amp Paraphrasing'}),
#  ('The Benefits of Taking a Writing Class->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The Benefits of Taking a Writing Class',
#    'tail': 'Writing Class'}),
#  ('A Beginner’s Guide to Writing That Novel->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'A Beginner’s Guide to Writing That Novel',
#    'tail': 'Novel'}),
#  ('The Future of Work Rethinking Document Management Systems DMS ->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The Future of Work Rethinking Document Management Systems DMS',
#    'tail': 'Document Management Systems DMS'}),
#  ('How Chatbots Are Changing The Insurance Gameplay.->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Chatbots Are Changing The Insurance Gameplay',
#    'tail': 'Chatbots'}),
#  ('Strategic or Tactical Programming? The Road Ahead for Software Engineers Data Driven Investor->(5, 11)',
#   {'relation': 'main subject',
#    'head': 'The Road Ahead for Software Engineers',
#    'tail': 'Data Driven Investor'}),
#  ('How To Be Productive Without Being Hard on Yourself->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How To Be Productive Without Being Hard on Yourself',
#    'tail': 'Productive'}),
#  ('The Art and Science of Data Visualization->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The Art and Science of Data Visualization',
#    'tail': 'Data Visualization'}),
#  ('From Cups to Consciousness Part 3 Mapping your home with SLAM->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'From Cups to Consciousness Part 3',
#    'tail': 'SLAM'}),
#  ('Five Tips for Contributing to Open Source Software->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Five Tips for Contributing to Open Source Software',
#    'tail': 'Open Source Software'}),
#  ('The Unexpected Lesson Within A Jelly Bean Jar->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The Unexpected Lesson Within A Jelly Bean Jar',
#    'tail': 'Jelly Bean Jar'}),
#  ('A firsthand tale of letting the lights go out the conscious uncoupling of sales and success->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'A firsthand tale of letting the lights go out',
#    'tail': 'conscious uncoupling of sales and success'}),
#  ('If You Learn to Write, You Can Change Your Life.->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'If You Learn to Write, You Can Change Your Life',
#    'tail': 'Learn to Write'}),
#  ('The Power of Letting Go How Surrendering Control Can Improve Your Life->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'The Power of Letting Go How Surrendering Control Can Improve Your Life',
#    'tail': 'Surrendering Control'}),
#  ('A practical guide to get started with DataOps->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'A practical guide to get started with DataOps',
#    'tail': 'DataOps'}),
#  ('If You’re Transgender, You Need to Write->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'If You’re Transgender, You Need to Write',
#    'tail': 'Transgender'}),
#  ('An Introduction to Vision Statements->(1, 3)',
#   {'relation': 'main subject',
#    'head': 'Introduction to Vision Statements',
#    'tail': 'Vision Statements'}),
#  ('The Good, The Bad & The Ugly of NaNoWriMo->(0, 9)',
#   {'relation': 'main subject',
#    'head': 'The Good, The Bad & The Ugly of NaNoWriMo',
#    'tail': 'NaNoWriMo'}),
#  ('Bullet Journals Cultivating Intentionality for Beginners->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Bullet Journals',
#    'tail': 'Intentionality'}),
#  ('How to Avoid Killing Your Partner When You Both Work From Home->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to Avoid Killing Your Partner When You Both Work From Home',
#    'tail': 'Killing Your Partner When You Both Work From Home'}),
#  ('Why You Need to Be a Quitter->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Why You Need to Be a Quitter',
#    'tail': 'Quitter'}),
#  ('The Importance of Self Discipline->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Importance of Self Discipline',
#    'tail': 'Self Discipline'}),
#  ('Why Bullet Journals Don’t Need to Be Fancy to Be Functional->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Bullet Journals Don’t Need to Be Fancy to Be Functional',
#    'tail': 'Bullet Journals Don’t Need to Be Fancy to Be Functional'}),
#  ('Why STEM Needs the Liberal Arts->(1, 4)',
#   {'relation': 'main subject',
#    'head': 'STEM Needs the Liberal Arts',
#    'tail': 'Liberal Arts'}),
#  ('When a Friend Dumps You->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'When a Friend Dumps You',
#    'tail': 'Friend Dumps You'}),
#  ('The Art of Productive Procrastination->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Art of Productive Procrastination',
#    'tail': 'Procrastination'}),
#  ('The Emotional Magic of Relaxing Your Boundaries->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Emotional Magic of Relaxing Your Boundaries',
#    'tail': 'Relaxing Your Boundaries'}),
#  ('Why You Should Not Be Ashamed of Crying at Work->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Why You Should Not Be Ashamed of Crying at Work',
#    'tail': 'Crying at Work'}),
#  ('How to Be More Productive with Your Free Time->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'How to Be More Productive with Your Free Time',
#    'tail': 'Free Time'}),
#  ('Between Earnest and Jest A Fight Over YouTube’s Identity->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Between Earnest and Jest',
#    'tail': 'YouTube’s Identity'}),
#  ('How to Tell If You’re Overthinking a Decision->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How to Tell If You’re Overthinking a Decision',
#    'tail': 'Overthinking a Decision'}),
#  ('How Small Gigs Lead To Big Success->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Small Gigs Lead To Big Success',
#    'tail': 'Small Gigs'}),
#  ('How to Get In Harmony With Your Life->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How to Get In Harmony With Your Life',
#    'tail': 'Harmony With Your Life'}),
#  ('Practical Tips for Writing Awesome Dialogue For Beginners->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Practical Tips for Writing Awesome Dialogue For Beginners',
#    'tail': 'Awesome Dialogue'}),
#  ('How to Deal with a Freelancing Slump->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'How to Deal with a Freelancing Slump',
#    'tail': 'Freelancing Slump'}),
#  ('Writing for the Pharmaceutical Industry->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Writing for the Pharmaceutical Industry',
#    'tail': 'Pharmaceutical Industry'}),
#  ('Become a Writing Machine Crafty Ways to Write Faster->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Become a Writing Machine',
#    'tail': 'Crafty Ways to Write Faster'}),
#  ('Why I Hate Graphs.->(0, 3)',
#   {'relation': 'main subject', 'head': 'Why I Hate Graphs', 'tail': 'Graphs'}),
#  ('5 Ways a Career Glitch Is Good For You->(0, 3)',
#   {'relation': 'main subject',
#    'head': '5 Ways a Career Glitch Is Good For You',
#    'tail': 'Career Glitch'}),
#  ('Recently in Better Humans Fresh Takes on Relationships, Mindset, Diversity, and Citizen Journalism->(2, 14)',
#   {'relation': 'main subject',
#    'head': 'Better Humans',
#    'tail': 'Citizen Journalism'}),
#  ('A 3 Part Guide for New Writers on Medium->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'A 3 Part Guide for New Writers on Medium',
#    'tail': 'Medium'}),
#  ('Sentiment Analysis for Hotel Reviews->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Sentiment Analysis for Hotel Reviews',
#    'tail': 'Hotel Reviews'}),
#  ('The One with all the FRIENDS Analysis->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'The One with all the FRIENDS Analysis',
#    'tail': 'FRIENDS'}),
#  ('An Introduction to Autonomous Vehicles->(1, 3)',
#   {'relation': 'main subject',
#    'head': 'Introduction to Autonomous Vehicles',
#    'tail': 'Autonomous Vehicles'}),
#  ('An Overview of Computer Vision->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'An Overview of Computer Vision',
#    'tail': 'Computer Vision'}),
#  ('Math for Data Science Collaborative Filtering on Utility Matrices->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Math for Data Science',
#    'tail': 'Data Science'}),
#  ('100 Days of Artificial Intelligence->(0, 3)',
#   {'relation': 'main subject',
#    'head': '100 Days of Artificial Intelligence',
#    'tail': 'Artificial Intelligence'}),
#  ('Keeping Data Science Scientific->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Keeping Data Science Scientific',
#    'tail': 'Data Science'}),
#  ('Sporks, Toy Story 4, and Product Design->(2, 7)',
#   {'relation': 'main subject',
#    'head': 'Toy Story 4',
#    'tail': 'Product Design'}),
#  ('We’re Getting Happy Wrong Why We Need a More Sustainable Model of Happiness->(5, 13)',
#   {'relation': 'main subject',
#    'head': 'Why We Need a More Sustainable Model of Happiness',
#    'tail': 'Happiness'}),
#  ('A 6 Simple Steps Plan To Build A Millionnaire Mindset->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'A 6 Simple Steps Plan To Build A Millionnaire Mindset',
#    'tail': 'A Millionnaire Mindset'}),
#  ('Why the Music Industry Needs Blockchain->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Why the Music Industry Needs Blockchain',
#    'tail': 'Music Industry'}),
#  ('10 Easy Ways To Boost Your Immune System->(0, 4)',
#   {'relation': 'main subject',
#    'head': '10 Easy Ways To Boost Your Immune System',
#    'tail': 'Boost Your Immune System'}),
#  ('I Finally Got a Bra Fitting->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'I Finally Got a Bra Fitting',
#    'tail': 'Bra Fitting'}),
#  ('Raising Venture Capital And Saving Our Oceans ->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Raising Venture Capital',
#    'tail': 'Saving Our Oceans'}),
#  ('The Hardest Part About Learning Hard Things->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Hardest Part About Learning Hard Things',
#    'tail': 'Learning Hard Things'}),
#  ('Why I Love And Hate Copywriting->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Why I Love And Hate Copywriting',
#    'tail': 'Copywriting'}),
#  ('Four reasons perfectionism is ruining your life->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Four reasons perfectionism is ruining your life',
#    'tail': 'perfectionism'}),
#  ('Self Love Is Not Arrogant->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Self Love Is Not Arrogant',
#    'tail': 'Self Love Is Not Arrogant'}),
#  ('A Practical Guide to Practice->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'A Practical Guide to Practice',
#    'tail': 'Practice'}),
#  ('7 Steps to Becoming a Better Programmer->(0, 6)',
#   {'relation': 'main subject',
#    'head': '7 Steps to Becoming a Better Programmer',
#    'tail': 'Programmer'}),
#  ('Silent Wars Creating Peace in Relationships and Home->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Silent Wars',
#    'tail': 'Peace in Relationships and Home'}),
#  ('How to get the perfect.COM domain on a budget->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How to get the perfect',
#    'tail': 'perfect'}),
#  ('How to Maintain Strong Willpower->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to Maintain Strong Willpower',
#    'tail': 'Strong Willpower'}),
#  ('The 50 State Anti Trust Investigation Into Big Tech Promises Accountability->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'The 50 State Anti Trust Investigation Into Big Tech Promises Accountability',
#    'tail': 'Big Tech Promises Accountability'}),
#  ('Using Data for Social Good->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Using Data for Social Good',
#    'tail': 'Data for Social Good'}),
#  ('Windows of Empowerment->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Windows of Empowerment',
#    'tail': 'Empowerment'}),
#  ('Society Has A Predefined Flow You Don’t Need To Follow It->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Society Has A Predefined Flow',
#    'tail': 'Predefined Flow'}),
#  ('Dear Slow Writer, You Are Not Alone. Tips From A Professional Writer.->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Dear Slow Writer, You Are Not Alone',
#    'tail': 'Slow Writer'}),
#  ('Dear Slow Writer, You Are Not Alone. Tips From A Professional Writer.->(9, 12)',
#   {'relation': 'main subject',
#    'head': 'Tips From A Professional Writer',
#    'tail': 'Professional Writer'}),
#  ('Why You Should Write for Writers->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Why You Should Write for Writers',
#    'tail': 'Write for Writers'}),
#  ('What’s Your Story? The Key to Building Your Brand->(5, 10)',
#   {'relation': 'main subject',
#    'head': 'The Key to Building Your Brand',
#    'tail': 'Brand'}),
#  ('7 Valuable Ways to Attract New Investors with Digital->(0, 8)',
#   {'relation': 'main subject',
#    'head': '7 Valuable Ways to Attract New Investors with Digital',
#    'tail': 'Digital'}),
#  ('How to Use Science of Meditation to Motivate Your Own Meditation Habit->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'How to Use Science of Meditation to Motivate Your Own Meditation Habit',
#    'tail': 'Meditation'}),
#  ('How To Handle Other People’s Bad Moods Like a Pro->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How To Handle Other People’s Bad Moods Like a Pro',
#    'tail': 'Bad Moods'}),
#  ('How To Create a Passive Income Machine->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How To Create a Passive Income Machine',
#    'tail': 'Passive Income'}),
#  ('5 Harsh Truths About Building Your Writing Career Other Gurus Won’t Tell You->(0, 6)',
#   {'relation': 'main subject',
#    'head': '5 Harsh Truths About Building Your Writing Career Other Gurus Won’t Tell You',
#    'tail': 'Writing Career'}),
#  ('How To Stay Successful in a Rapidly Changing World->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How To Stay Successful in a Rapidly Changing World',
#    'tail': 'Stay Successful in a Rapidly Changing World'}),
#  ('How To Ethically Market Alcohol Products->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How To Ethically Market Alcohol Products',
#    'tail': 'Ethically Market'}),
#  ('Why Nobody Cares About Your Data Science Project->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Why Nobody Cares About Your Data Science Project',
#    'tail': 'Data Science'}),
#  ('The Case for Data Science as the Modern Liberal Arts->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Case for Data Science as the Modern Liberal Arts',
#    'tail': 'Data Science'}),
#  ('When Your Morning Routine Becomes a Burden And how to Create One That Actually Serves You->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'When Your Morning Routine Becomes a Burden And how to Create One That Actually Serves You',
#    'tail': 'Morning Routine'}),
#  ('Making Time for Mindfulness Changed My Life->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Making Time for Mindfulness Changed My Life',
#    'tail': 'Mindfulness'}),
#  ('How Going Digital Has Given Me More Freedom and Time->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Going Digital Has Given Me More Freedom and Time',
#    'tail': 'Going Digital'}),
#  ('Let’s Talk About Debt, Baby->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Let’s Talk About Debt, Baby',
#    'tail': 'Baby'}),
#  ('Your Story is Important.->(1, 0)',
#   {'relation': 'main subject',
#    'head': 'Story is Important',
#    'tail': 'Your Story'}),
#  ('The Competitive Advantage of Large Uninterrupted Blocks of Free Time->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Competitive Advantage of Large Uninterrupted Blocks of Free Time',
#    'tail': 'Competitive Advantage'}),
#  ('Why You Need To Write If You Want To Inspire Action->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Why You Need To Write If You Want To Inspire Action',
#    'tail': 'Write If You Want To Inspire Action'}),
#  ('A Quick Guide On How To Get Started As A Freelance Copywriter->(0, 11)',
#   {'relation': 'main subject',
#    'head': 'A Quick Guide On How To Get Started As A Freelance Copywriter',
#    'tail': 'Copywriter'}),
#  ('Flask for Beginners->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Flask for Beginners',
#    'tail': 'Beginners'}),
#  ('The End of the Wealth of Nations->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The End of the Wealth of Nations',
#    'tail': 'Wealth of Nations'}),
#  ('What Would a World Without Facebook Look Like?->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'What Would a World Without Facebook Look Like',
#    'tail': 'Facebook'}),
#  ('Managing the Need to Provide->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Managing the Need to Provide',
#    'tail': 'Need to Provide'}),
#  ('Real Talk with the Director of Data Science at Columbia University->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Real Talk with the Director of Data Science at Columbia University',
#    'tail': 'Data Science'}),
#  ('Autonomous Agents And Multi Agent Systems 101 Agents And Deception->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Autonomous Agents And Multi Agent Systems 101 Agents And Deception',
#    'tail': 'Agents And Deception'}),
#  ('The Impact of Marijuana Legalization on Traffic Deaths A Synthetic Control Approach->(0, 9)',
#   {'relation': 'main subject',
#    'head': 'The Impact of Marijuana Legalization on Traffic Deaths',
#    'tail': 'Synthetic Control'}),
#  ('Why We Need To Rethink Central Authority In The Age of AI->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Why We Need To Rethink Central Authority',
#    'tail': 'Central Authority'}),
#  ('Why We Need To Rethink Central Authority In The Age of AI->(7, 8)',
#   {'relation': 'main subject',
#    'head': 'In The Age of AI',
#    'tail': 'The Age of AI'}),
#  ('How to Code Effectively Without Dying in the Attempt->(0, 2)',
#   {'relation': 'main subject',
# ...
#    'tail': 'Open Yourself Up to New Possibilities'}),
#  ('How to Foster Deeper Connections with Your First Customers->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'How to Foster Deeper Connections with Your First Customers',
#    'tail': 'Deeper Connections'}),
#  ('The Rise Of Digital Asset Custody Solutions Data Driven Investor->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Rise Of Digital Asset Custody Solutions',
#    'tail': 'Digital Asset Custody Solutions'}),
#  ('Myths and Mistakes of the Ketogenic Diet->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Myths and Mistakes of the Ketogenic Diet',
#    'tail': 'Ketogenic Diet'}),
#  ('FGO StyleGAN This Heroic Spirit Doesn’t Exist->(2, 3)',
#   {'relation': 'main subject',
#    'head': 'This Heroic Spirit Doesn’t Exist',
#    'tail': 'Heroic Spirit'}),
#  ('The Amazing Flywheel Effect->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'The Amazing Flywheel Effect',
#    'tail': 'Flywheel'}),
#  ('The Problem With Always Jumping To The Next Thing->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Problem With Always Jumping To The Next Thing',
#    'tail': 'Always Jumping To The Next Thing'}),
#  ('6 Simple Ways to Cope Better with Big Life Changes->(0, 7)',
#   {'relation': 'main subject',
#    'head': '6 Simple Ways to Cope Better with Big Life Changes',
#    'tail': 'Big Life Changes'}),
#  ('Why The Guardian Is Changing How It Talks About Climate Change->(1, 9)',
#   {'relation': 'main subject',
#    'head': 'The Guardian Is Changing How It Talks About Climate Change',
#    'tail': 'Climate Change'}),
#  ('Stop, Start, Continue My Thoughts for Elementary Math Teachers->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'Stop, Start, Continue My Thoughts for Elementary Math Teachers',
#    'tail': 'Elementary Math Teachers'}),
#  ('Etiquette in a Remote Company->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Etiquette in a Remote Company',
#    'tail': 'Remote Company'}),
#  ('The Three Most Unexplored Aspects of A Job Switch in Early Career Transitions->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'The Three Most Unexplored Aspects of A Job Switch in Early Career Transitions',
#    'tail': 'Early Career Transitions'}),
#  ('Is Unfulfilling Work Slowly Killing You?->(1, 1)',
#   {'relation': 'main subject',
#    'head': 'Unfulfilling Work Slowly Killing You',
#    'tail': 'Unfulfilling Work'}),
#  ('The Future of Corporate Wellness Programs->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Future of Corporate Wellness Programs',
#    'tail': 'Corporate Wellness'}),
#  ('How to Effortlessly Fill a Sketchbook in 30 Days->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'How to Effortlessly Fill a Sketchbook in 30 Days',
#    'tail': 'Sketchbook'}),
#  ('The Life Changing Magic of Having A Mentor->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'The Life Changing Magic of Having A Mentor',
#    'tail': 'Mentor'}),
#  ('How I’m Curating My Own Instagram Experience->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'How I’m Curating My Own Instagram Experience',
#    'tail': 'Instagram'}),
#  ('Surviving the Chronic Depths of the Contemplative Temperament->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Surviving the Chronic Depths of the Contemplative Temperament',
#    'tail': 'Contemplative Temperament'}),
#  ('Six More Things About the Boeing 737 MAX Crisis->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Six More Things About the Boeing 737 MAX Crisis',
#    'tail': 'Boeing 737 MAX Crisis'}),
#  ('Stop Thinking Freelancers Are Desperate to Make A Quick Buck->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Stop Thinking Freelancers Are Desperate to Make A Quick Buck',
#    'tail': 'Freelancers Are Desperate to Make A Quick Buck'}),
#  ('5 Investment Lessons To Create A Prosperous Financial Future For You And Those You Love->(0, 6)',
#   {'relation': 'main subject',
#    'head': '5 Investment Lessons To Create A Prosperous Financial Future For You And Those You Love',
#    'tail': 'Prosperous Financial Future For You And Those You Love'}),
#  ('5 Elements For Improving Reader Engagement Not Another Headline Article->(0, 4)',
#   {'relation': 'main subject',
#    'head': '5 Elements For Improving Reader Engagement Not Another Headline Article',
#    'tail': 'Reader Engagement Not Another Headline Article'}),
#  ('The Fear of Starting a New Novel->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'The Fear of Starting a New Novel',
#    'tail': 'Novel'}),
#  ('Delirium, Reality, and the Contours of the Mind reflections on my post operative experiences in intensive care->(0, 17)',
#   {'relation': 'main subject',
#    'head': 'Delirium, Reality, and the Contours of the Mind',
#    'tail': 'intensive care'}),
#  ('But That’s a Girls’ Book Addressing a Literary Double Standard->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'But That’s a Girls’ Book Addressing a Literary Double Standard',
#    'tail': 'Girls’ Book'}),
#  ('Why Can’t You Finish Your First Draft?->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Why Can’t You Finish Your First Draft',
#    'tail': 'Why Can’t You Finish Your First Draft'}),
#  ('Getting Over Myself Has Been a Challenge->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Getting Over Myself',
#    'tail': 'Challenge'}),
#  ('A Fine Balance Writing and Life->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'A Fine Balance Writing and Life',
#    'tail': 'Writing'}),
#  ('The Death Of Consumer Startups?->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Death Of Consumer Startups',
#    'tail': 'Startups'}),
#  ('The Employment Based Economy WILL Soon Fail What Can We do to Avoid Disaster?->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'The Employment Based Economy WILL Soon Fail',
#    'tail': 'Employment Based Economy'}),
#  ('I Am A Pizza->(0, 3)',
#   {'relation': 'main subject', 'head': 'I Am A Pizza', 'tail': 'Pizza'}),
#  ('A 3 Step Method for Making Quicker and Better Decisions->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'A 3 Step Method for Making Quicker and Better Decisions',
#    'tail': '3 Step Method'}),
#  ('3 Magical Business Lessons I Learned From the Walt Disney Company->(0, 8)',
#   {'relation': 'main subject',
#    'head': '3 Magical Business Lessons I Learned From the Walt Disney Company',
#    'tail': 'Walt Disney Company'}),
#  ('15 Artificial Intelligence Books You Should Read->(0, 1)',
#   {'relation': 'main subject',
#    'head': '15 Artificial Intelligence Books You Should Read',
#    'tail': 'Artificial Intelligence'}),
#  ('I liked the New Math->(3, 4)',
#   {'relation': 'main subject', 'head': 'New Math', 'tail': 'Math'}),
#  ('Calculating the odds you sit next to your ex on a flight this holiday season->(0, 13)',
#   {'relation': 'main subject',
#    'head': 'Calculating the odds you sit next to your ex on a flight',
#    'tail': 'holiday season'}),
#  ('The many experiences of Christmas->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The many experiences of Christmas',
#    'tail': 'Christmas'}),
#  ('4 Reasons Why Bitcoin Could Die And Why It Will Not Happen->(0, 3)',
#   {'relation': 'main subject',
#    'head': '4 Reasons Why Bitcoin Could Die',
#    'tail': 'Bitcoin'}),
#  ('Why Reinforcement Learning is Wrong for Your Business->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why Reinforcement Learning is Wrong for Your Business',
#    'tail': 'Reinforcement Learning'}),
#  ('An Ultimate Guide to Creating a Startup->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'An Ultimate Guide to Creating a Startup',
#    'tail': 'Startup'}),
#  ('The Toxic Effect of Glorifying Hard Work->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Toxic Effect of Glorifying Hard Work',
#    'tail': 'Glorifying Hard Work'}),
#  ('AmazonSmile, Value, and the Ethics of Participation->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'AmazonSmile',
#    'tail': 'Ethics of Participation'}),
#  ('Writing for Thirty Minutes a Day Might Be All You Need->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Writing for Thirty Minutes a Day Might Be All You Need',
#    'tail': 'Thirty Minutes a Day'}),
#  ('Taking the Plunge and Starting a Writing Career Has Changed My Life in Twelve Days->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Taking the Plunge and Starting a Writing Career Has Changed My Life in Twelve Days',
#    'tail': 'Writing Career'}),
#  ('Functional Connectomics A Novel Approach to Study the Brain->(0, 8)',
#   {'relation': 'main subject',
#    'head': 'Functional Connectomics',
#    'tail': 'Brain'}),
#  ('The Easiest Way To Save Money->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Easiest Way To Save Money',
#    'tail': 'Save Money'}),
#  ('Why The Value Imperative Will Cure Your Productivity Woes->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Why The Value Imperative Will Cure Your Productivity Woes',
#    'tail': 'The Value Imperative'}),
#  ('Why Your Student Loan Balance Isn’t Going Down->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Why Your Student Loan Balance Isn’t Going Down',
#    'tail': 'Student Loan Balance'}),
#  ('How to Begin Your Creative Day->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How to Begin Your Creative Day',
#    'tail': 'Creative Day'}),
#  ('3 Underrated Ways of Increasing Your Daily Productivity->(0, 6)',
#   {'relation': 'main subject',
#    'head': '3 Underrated Ways of Increasing Your Daily Productivity',
#    'tail': 'Daily Productivity'}),
#  ('When Will Self Driving Cars Arrive in the UK?->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'When Will Self Driving Cars Arrive in the UK',
#    'tail': 'Self Driving Cars'}),
#  ('Accepting Rejection for What It Is->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Accepting Rejection for What It Is',
#    'tail': 'Accepting Rejection'}),
#  ('How a chicken is helping humans with grammar->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How a chicken is helping humans with grammar',
#    'tail': 'chicken'}),
#  ('How Rejection Will Make You a Better Entrepreneur->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'How Rejection Will Make You a Better Entrepreneur',
#    'tail': 'Rejection Will Make You a Better Entrepreneur'}),
#  ('Enough with the Tracking Already->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Enough with the Tracking Already',
#    'tail': 'Tracking'}),
#  ('Great Leaders Know How to Deal with Anger->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Great Leaders Know How to Deal with Anger',
#    'tail': 'Anger'}),
#  ('3 Big Limiting Beliefs Holding You Back->(0, 2)',
#   {'relation': 'main subject',
#    'head': '3 Big Limiting Beliefs Holding You Back',
#    'tail': 'Limiting Beliefs Holding You Back'}),
#  ('How Your Media Diet Can Be Making You Sick->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How Your Media Diet Can Be Making You Sick',
#    'tail': 'Media Diet'}),
#  ('A Logical Reason for All Time High Stock Markets->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'A Logical Reason for All Time High Stock Markets',
#    'tail': 'Logical Reason'}),
#  ('Are You Writing Through The Holidays?->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Are You Writing Through The Holidays',
#    'tail': 'Writing Through The Holidays'}),
#  ('Writing the Perfect Ending->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Writing the Perfect Ending',
#    'tail': 'Perfect Ending'}),
#  ('How to Embrace Your Failures and Cultivate Expertise->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'How to Embrace Your Failures and Cultivate Expertise',
#    'tail': 'Embrace Your Failures and Cultivate Expertise'}),
#  ('What I’d Do Differently as a Beginner Writer->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'What I’d Do Differently as a Beginner Writer',
#    'tail': 'Beginner Writer'}),
#  ('Dollar General and the Economics of Rural America Market Mad House->(0, 6)',
#   {'relation': 'main subject',
#    'head': 'Dollar General and the Economics of Rural America Market Mad House',
#    'tail': 'Rural America'}),
#  ('The Customer Expectation Matrix Marketing Wisdom From a Biker->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Customer Expectation Matrix',
#    'tail': 'Marketing'}),
#  ('Your Brainstorming Process Is Broken How To Generate Ideas More Effectively->(0, 1)',
#   {'relation': 'main subject',
#    'head': 'Your Brainstorming Process Is Broken How To Generate Ideas More Effectively',
#    'tail': 'Brainstorming'}),
#  ('Confessions of a Bitcoin Trader->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Confessions of a Bitcoin Trader',
#    'tail': 'Bitcoin Trader'}),
#  ('7 Great Tips On Talking To People You Don’t Know At A Party->(0, 4)',
#   {'relation': 'main subject',
#    'head': '7 Great Tips On Talking To People You Don’t Know At A Party',
#    'tail': 'Talking To People You Don’t Know At A Party'}),
#  ('Daily routine 5 reasons why you should create one for yourself->(0, 2)',
#   {'relation': 'main subject',
#    'head': 'Daily routine',
#    'tail': '5 reasons why you should create one for yourself'}),
#  ('Is There a Future for McDonald’s?->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'Is There a Future for McDonald’s',
#    'tail': 'McDonald’s'}),
#  ('How Not To Be A Douche->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'How Not To Be A Douche',
#    'tail': 'Douche'}),
#  ('Four Simple Ways to Be Extraordinary->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'Four Simple Ways to Be Extraordinary',
#    'tail': 'Be Extraordinary'}),
#  ('30 Days With No Social Media, or News. A Personal Experiment->(11, 11)',
#   {'relation': 'main subject',
#    'head': 'Personal Experiment',
#    'tail': 'Personal Experiment'}),
#  ('The Lost Art Of Focus.->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'The Lost Art Of Focus',
#    'tail': 'Focus'}),
#  ('The Beauty of Impermanence->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Beauty of Impermanence',
#    'tail': 'Impermanence'}),
#  ('Should Companies Change Work Hours to Support Night Owls?->(0, 7)',
#   {'relation': 'main subject',
#    'head': 'Should Companies Change Work Hours to Support Night Owls',
#    'tail': 'Night Owls'}),
#  ('The MAGIC of Exponential Growth and Compound Interest->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The MAGIC of Exponential Growth and Compound Interest',
#    'tail': 'Exponential Growth'}),
#  ('How To Align Your Company’s Security Practices With The Human Brain->(0, 9)',
#   {'relation': 'main subject',
#    'head': 'How To Align Your Company’s Security Practices With The Human Brain',
#    'tail': 'The Human Brain'}),
#  ('How to Make a Memorable First Day->(0, 5)',
#   {'relation': 'main subject',
#    'head': 'How to Make a Memorable First Day',
#    'tail': 'First Day'}),
#  ('How to Get the Most Out of Working with a Graphic Designer->(0, 10)',
#   {'relation': 'main subject',
#    'head': 'How to Get the Most Out of Working with a Graphic Designer',
#    'tail': 'Graphic Designer'}),
#  ('Leading By Example->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Leading By Example',
#    'tail': 'Leading By Example'}),
#  ('How to Develop Your Authenticity Muscle->(0, 4)',
#   {'relation': 'main subject',
#    'head': 'How to Develop Your Authenticity Muscle',
#    'tail': 'Authenticity'}),
#  ('The Value of Boredom->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'The Value of Boredom',
#    'tail': 'Boredom'}),
#  ('5 Leadership Skills Taught by a Horse->(0, 1)',
#   {'relation': 'main subject',
#    'head': '5 Leadership Skills Taught by a Horse',
#    'tail': 'Leadership'}),
#  ('A Framework for Privacy->(1, 3)',
#   {'relation': 'main subject',
#    'head': 'Framework for Privacy',
#    'tail': 'Privacy'}),
#  ('Your Idea Didn’t Fail Because Of Lack Of Money Or Your Inability To Execute It->(0, 0)',
#   {'relation': 'main subject',
#    'head': 'Your Idea Didn’t Fail Because Of Lack Of Money Or Your Inability To Execute It',
#    'tail': 'Your Idea Didn’t Fail Because Of Lack Of Money Or Your Inability To Execute It'}),
#  ('Shield Law Should Protect All Journalists->(0, 3)',
#   {'relation': 'main subject',
#    'head': 'Shield Law Should Protect All Journalists',
#    'tail': 'Protect All Journalists'}),
#  ...]
